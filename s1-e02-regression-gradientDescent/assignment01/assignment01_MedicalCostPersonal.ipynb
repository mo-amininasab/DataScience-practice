# %% [markdown]
# # Medical Cost Personal Datasets
# The data is comprised of insurance costs for over 1,300 patients and includes information such as age, BMI, charges, etc.
#
# ### Source:
# [https://www.kaggle.com/mirichoi0218/insurance](https://www.kaggle.com/mirichoi0218/insurance)
#
# ### Problem Definition:
# In this case, the problem we will be exploring is **regression**.
#
# This is because we're going to be using a number of different **features** (pieces of information) about medical information to **estimate** the charges.
#
# ### Records:
# The dataset contains a total of 1338 cases.
#
# ### Features:
# * **age**: age of primary beneficiary
# * **sex**: insurance contractor gender, female, male
# * **bmi**: Body mass index, providing an understanding of body, weights that are relatively high or low relative to height,
# objective index of body weight (kg / m ^ 2) using the ratio of height to weight, ideally 18.5 to 24.9
# * **children**: Number of children covered by health insurance / Number of dependents
# * **smoker**: Smoking
# * **region**: the beneficiary's residential area in the US, northeast, southeast, southwest, northwest.
# * **charges**: Individual medical costs billed by health insurance

# %% [markdown]
# ## Preparing the tools

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Getting data ready

# %%
dataset_url = 'https://raw.githubusercontent.com/mohammad-amini-nasab/DataScience-practice/main/s1-e02-regression-gradientDescent/insurance.csv'
insurance = pd.read_csv(dataset_url)
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# Information about data

# %%
insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
insurance.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# ### Categorical data

# %%
insurance.select_dtypes(include=['object']).head()
# Out:
#       sex smoker     region
# 0  female    yes  southwest
# 1    male     no  southeast
# 2    male     no  southeast
# 3    male     no  northwest
# 4    male     no  northwest

# %%
sex = dict(insurance['sex'].value_counts())
sex_labels = list(sex.keys())
sex_counts = list(sex.values())

smoker = dict(insurance['smoker'].value_counts())
smoker_labels = list(smoker.keys())
smoker_counts = list(smoker.values())

region = dict(insurance['region'].value_counts())
region_labels = list(region.keys())
region_counts = list(region.values())

# %%
fig, axes = plt.subplots(3, 2, figsize=(10, 7), dpi=100)
axes = axes.flatten()

axes[0].barh(sex_labels, sex_counts)
axes[0].set_title('sex distribution bar chart')
axes[0].set_xlabel('Count')

axes[1].pie(sex_counts,labels=sex_labels, wedgeprops={'edgecolor':'black'}, autopct='%1.1f%%')
axes[1].set_title('sex distribution pie chart')

axes[2].barh(smoker_labels, smoker_counts)
axes[2].set_title('smoker distribution bar chart')
axes[2].set_xlabel('Count')

axes[3].pie(smoker_counts,labels=smoker_labels, wedgeprops={'edgecolor':'black'}, autopct='%1.1f%%')
axes[3].set_title('smoker distribution pie chart')

axes[4].barh(region_labels, region_counts)
axes[4].set_title('region distribution bar chart')
axes[4].set_xlabel('Count')

axes[5].pie(region_counts,labels=region_labels, wedgeprops={'edgecolor':'black'}, autopct='%1.1f%%')
axes[5].set_title('region distribution pie chart')

plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=2.0)

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# #### Converting categorical data to numeric data

# %%
obj_df = insurance.select_dtypes(include=['object']).copy()

# %% [markdown]
# Column *sex*: considering *female* is *0* and *male* is *1*.\
# Column *smoker*: considering *no* is *0* and *yes* is *1*.
# <!-- Column *region*: One Hot encoded. -->

# %%
insurance['sex'].replace(['female', 'male'], [0, 1], inplace=True)
insurance['smoker'].replace(['no', 'yes'], [0, 1], inplace=True)

# insurance = pd.get_dummies(insurance, columns=['region'])
insurance.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    0  27.900         0       1  southwest  16884.92400
# 1   18    1  33.770         1       0  southeast   1725.55230
# 2   28    1  33.000         3       0  southeast   4449.46200
# 3   33    1  22.705         0       0  northwest  21984.47061
# 4   32    1  28.880         0       0  northwest   3866.85520

# %%
insurance.dtypes
# Out:
# age           int64
# sex           int64
# bmi         float64
# children      int64
# smoker        int64
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# #### Deal with null values
#
# There is no null value.

# %%
insurance.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# #### Finding outliers

# %%
# dropping Discrete data
data = insurance.drop(['sex', 'smoker', 'region'], axis=1)

# %%
def outlier_percentage(data):
  for k, v in data.items():
    q1 = v.quantile(0.25)
    q3 = v.quantile(0.75)
    irq = q3 - q1
    v_col = v[(v <= q1 - 1.5 * irq) | (v >= q3 + 1.5 * irq)]
    perc = np.shape(v_col)[0] * 100.0 / np.shape(data)[0]
    print("Column %s outliers = %.2f%%" % (k, perc))

# %%
# box and whisker plots
fig, axs = plt.subplots(ncols=4, nrows=1, figsize=(10, 5))
axs = axs.flatten()
for i, (k, v) in enumerate(data.items()):
  sns.boxplot(y=k, data=data, ax=axs[i])
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

outlier_percentage(data)
# Out:
# Column age outliers = 0.00%
# Column bmi outliers = 0.67%
# Column children outliers = 1.35%
# Column charges outliers = 10.39%

# %% [markdown]
# Removing *charges* outliers.

# %%
data = data[data['charges'] < 34000]

outlier_percentage(data)
# Out:
# Column age outliers = 0.00%
# Column bmi outliers = 1.01%
# Column children outliers = 1.51%
# Column charges outliers = 4.19%

# %%
fig, axs = plt.subplots(ncols=2, nrows=2, figsize=(11, 5))
axs = axs.flatten()
for i, (k, v) in enumerate(data.items()):
  sns.distplot(v, ax=axs[i])
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)
# Out:
# C:\Users\MAN\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\MAN\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...
