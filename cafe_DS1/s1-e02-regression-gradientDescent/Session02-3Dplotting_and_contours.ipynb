# %%
import numpy as np
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

fig = plt.figure()
#Plot Size
plt.rcParams['figure.figsize'] = (10, 10)



ax = fig.add_subplot(111, projection="3d")
xx = np.arange(-20,20,0.1)
yy = np.arange(-20,20,0.1)
X, Y = np.meshgrid(xx , yy)
Z = X ** 2 + Y ** 2
ax.plot_surface(X, Y, Z, cmap="viridis", lw=0.5, rstride=1, cstride=1)
ax.contour(X, Y, Z, 10, lw=2, cmap="viridis", linestyles="solid", offset=-1)
ax.contour(X, Y, Z, 10, lw=2, colors="k", linestyles="solid")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: UserWarning: The following kwargs were not used by contour: 'lw'
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: UserWarning: The following kwargs were not used by contour: 'lw'
