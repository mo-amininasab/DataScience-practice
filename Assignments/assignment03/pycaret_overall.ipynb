# %%
# !pip install pycaret shap --quiet

# %%
from pycaret.classification import *
from pycaret.datasets import get_data

# %% [markdown]
# ## Loading Data

# %%
diabetes = get_data('diabetes')
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                               0
# 1                               0
# 2                               0
# 3                              94
# 4                             168
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age (years)  Class variable
# 0           50               1
# 1           31               0
# 2           32               1
# 3           21               0
# 4           33               1

# %%
exp_clf = setup(diabetes, target='Class variable')
# or
# experiment = setup(df, target='target', categorical_features=cat_features)
# Out:
#                                Description             Value
# 0                               session_id              6975
# 1                                   Target    Class variable
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data          (768, 9)
# 5                           Missing Values             False
# 6                         Numeric Features                 7
# 7                     Categorical Features                 1
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (537, 23)
# 12                    Transformed Test Set         (231, 23)
# 13                      Shuffle Train-Test              True
# 14                     Stratify Train-Test             False
# 15                          Fold Generator   StratifiedKFold
# 16                             Fold Number                10
# 17                                CPU Jobs                -1
# 18                                 Use GPU             False
# 19                          Log Experiment             False
# 20                         Experiment Name  clf-default-name
# 21                                     USI              e950
# 22                         Imputation Type            simple
# 23          Iterative Imputation Iteration              None
# 24                         Numeric Imputer              mean
# 25      Iterative Imputation Numeric Model              None
# 26                     Categorical Imputer          constant
# 27  Iterative Imputation Categorical Model              None
# 28           Unknown Categoricals Handling    least_frequent
# 29                               Normalize             False
# 30                        Normalize Method              None
# 31                          Transformation             False
# 32                   Transformation Method              None
# 33                                     PCA             False
# 34                              PCA Method              None
# 35                          PCA Components              None
# 36                     Ignore Low Variance             False
# 37                     Combine Rare Levels             False
# 38                    Rare Level Threshold              None
# 39                         Numeric Binning             False
# 40                         Remove Outliers             False
# 41                      Outliers Threshold              None
# 42                Remove Multicollinearity             False
# 43             Multicollinearity Threshold              None
# 44             Remove Perfect Collinearity              True
# 45                              Clustering             False
# 46                    Clustering Iteration              None
# 47                     Polynomial Features             False
# 48                       Polynomial Degree              None
# 49                    Trignometry Features             False
# 50                    Polynomial Threshold              None
# 51                          Group Features             False
# 52                       Feature Selection             False
# 53                Feature Selection Method           classic
# 54            Features Selection Threshold              None
# 55                     Feature Interaction             False
# 56                           Feature Ratio             False
# 57                   Interaction Threshold              None
# 58                           Fix Imbalance             False
# 59                    Fix Imbalance Method             SMOTE

# %% [markdown]
# This resulting DataFrame is quite long and reports back a lot of information about your data. We can now proceed with the machine learning portion.

# %% [markdown]
# ## Finding the optimal algorithm

# %%
compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# ridge                    Ridge Classifier    0.7766  0.0000  0.5485  0.7254
# lr                    Logistic Regression    0.7709  0.8209  0.5538  0.7042
# knn                K Neighbors Classifier    0.7673  0.7606  0.5713  0.6918
# lda          Linear Discriminant Analysis    0.7635  0.8141  0.5485  0.6925
# rf               Random Forest Classifier    0.7615  0.8042  0.5158  0.6983
# lightgbm  Light Gradient Boosting Machine    0.7448  0.7897  0.5553  0.6490
# et                 Extra Trees Classifier    0.7393  0.7865  0.4605  0.6693
# gbc          Gradient Boosting Classifier    0.7374  0.8036  0.5319  0.6387
# ada                  Ada Boost Classifier    0.7319  0.7643  0.5161  0.6309
# nb                            Naive Bayes    0.6780  0.7239  0.2360  0.5566
# dt               Decision Tree Classifier    0.6704  0.6409  0.5491  0.5121
# dummy                    Dummy Classifier    0.6611  0.5000  0.0000  0.0000
# svm                   SVM - Linear Kernel    0.5979  0.0000  0.4722  0.3995
# qda       Quadratic Discriminant Analysis    0.5775  0.5693  0.3763  0.3483
#
#               F1   Kappa     MCC  TT (Sec)
# ridge     0.6194  0.4673  0.4792     0.023
# lr        0.6154  0.4571  0.4662     0.433
# knn       0.6209  0.4565  0.4640     0.128
# lda       0.6064  0.4421  0.4516     0.024
# rf        0.5919  0.4296  0.4400     0.556
# lightgbm  0.5927  0.4100  0.4167     0.063
# et        0.5432  0.3699  0.3838     0.507
# gbc       0.5773  0.3898  0.3953     0.182
# ada       0.5655  0.3750  0.3804     0.147
# nb        0.3226  0.1611  0.1870     0.019
# dt        0.5230  0.2744  0.2791     0.023
# dummy     0.0000  0.0000  0.0000     0.011
# svm       0.3994  0.1271  0.1370     0.022
# qda       0.3064  0.0501  0.0630     0.027
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, normalize=False, random_state=6975,
#                 solver='auto', tol=0.001)

# %%
ada = create_model('ada')
# or
# best_model = compare_models()
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.7593  0.8102  0.5000  0.6923  0.5806  0.4179  0.4288
# 1       0.7037  0.8071  0.5556  0.5556  0.5556  0.3333  0.3333
# 2       0.6296  0.7052  0.4444  0.4444  0.4444  0.1667  0.1667
# 3       0.7407  0.7546  0.5000  0.6429  0.5625  0.3824  0.3884
# 4       0.6852  0.6512  0.4444  0.5333  0.4848  0.2609  0.2631
# 5       0.8519  0.8617  0.6842  0.8667  0.7647  0.6588  0.6686
# 6       0.7037  0.7128  0.4211  0.6154  0.5000  0.2998  0.3107
# 7       0.6792  0.7222  0.3889  0.5385  0.4516  0.2332  0.2394
# 8       0.7736  0.8135  0.5556  0.7143  0.6250  0.4664  0.4740
# 9       0.7925  0.8048  0.6667  0.7059  0.6857  0.5310  0.5315
# Mean    0.7319  0.7643  0.5161  0.6309  0.5655  0.3750  0.3804
# Std     0.0613  0.0619  0.0949  0.1144  0.0982  0.1411  0.1426

# %% [markdown]
# ## Visualizing models performance

# %%
plot_model(ada) # shows the ROC curves plot by default

# %%
plot_model(ada, 'confusion_matrix')

# %%
plot_model(ada, 'class_report') # classification report

# %% [markdown]
# ## Model interpretation with SHAP
#
# SHAP, or SHapley Additive exPlanations, is a way to explain the outputs of a machine learning model. We can use it to see which features are most important by plotting the SHAP values of every feature for every sample.

# %%
# interpret_model(ada)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-0db32e118413> in <module>()
# ----> 1 interpret_model(ada)
#
# /usr/local/lib/python3.7/dist-packages/pycaret/classification.py in interpret_model(estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    1872         y_new_sample=y_new_sample,
#    1873         save=save,
# -> 1874         **kwargs,
#    1875     )
#    1876
#
# /usr/local/lib/python3.7/dist-packages/pycaret/internal/tabular.py in interpret_model(estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    7997     ):
#    7998         raise TypeError(
# -> 7999             f"This function only supports tree based models for binary classification: {', '.join(shap_models_ids)}."
#    8000         )
#    8001
#
# TypeError: This function only supports tree based models for binary classification: et, dt, lightgbm, rf.

# %% [markdown]
# ## Model evaluation and predictions
#
# PyCaret split the data into training and test portions (70:30) upon loading, so we don’t have to do it manually.\
# We can now evaluate the model on previously unseen data:

# %%
predictions = predict_model(ada)
# or
# predict_model(best_model, df.tail())
# Out:
#                   Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# 0  Ada Boost Classifier    0.7316  0.7611  0.5116  0.6875  0.5867  0.3942
#
#       MCC
# 0  0.4036

# %% [markdown]
# ## Model saving and loading
#
# Before saving the model, we need to finalize it:

# %%
finalize_model(ada)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,
#                    n_estimators=50, random_state=6975)

# %%
save_model(ada, 'diabetes_ada')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[],
#                                        target='Class variable',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeri...
#                  ('dummy', Dummify(target='Class variable')),
#                  ('fix_perfect', Remove_100(target='Class variable')),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#                                      learning_rate=1.0, n_estimators=50,
#                                      random_state=6975)]],
#           verbose=False), 'diabetes_ada.pkl')

# %%
model = load_model('diabetes_ada')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
model
# Out:
# Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[],
#                                       target='Class variable',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeri...
#                 ('dummy', Dummify(target='Class variable')),
#                 ('fix_perfect', Remove_100(target='Class variable')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                 ['trained_model',
#                  AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#                                     learning_rate=1.0, n_estimators=50,
#                                     random_state=6975)]],
#          verbose=False)

# %%
model.predict(diabetes.tail())
# Out:
# array([0, 0, 0, 1, 0])
