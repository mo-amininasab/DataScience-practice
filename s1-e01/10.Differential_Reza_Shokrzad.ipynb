# %% [markdown]
# # Derivative - Gradient - Chain Rule

# %% [markdown]
# ## Derivative Definition

# %%
def get_derivative(func, x):
    """Compute the derivative of `func` at the location `x`."""
    h = 0.0000001                          # step size
    return (func(x+h) - func(x)) / h    # rise-over-run - numerical (emprical)

def f(x): 
  return x**2                           # some test function f(x)=x^2

x = 3                                   # the location of interest
computed = get_derivative(f, x)
actual = 2*x

computed, actual                        # pretty close if you ask me...
# Out:
# (6.000000087880153, 6)

# %%
# SymPy Package
# !pip install sympy

# %% [markdown]
# *SymPy* is a Python library for symbolic mathematics. It aims to become a full-featured computer algebra system (CAS) while keeping the code as simple as possible in order to be comprehensible and easily extensible. SymPy is written entirely in Python.
#
#
# https://www.sympy.org/en/index.html

# %%
import sympy as sym

# %%
x = sym.Symbol('x')

# %%
sym.diff(x**5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\AppData\Roaming\Python\Python39\site-packages\sympy\core\_print_helpers.py in _repr_latex_(self)
#      62         """
#      63         from sympy.printing.latex import latex
# ---> 64         s = latex(self, mode='plain')
#      65         return "$\\displaystyle %s$" % s
#
# ~\AppData\Roaming\Python\Python39\site-packages\sympy\printing\printer.py in __call__(self, *args, **kwargs)
#     371
#     372     def __call__(self, *args, **kwargs):
# --> 373         return self.__wrapped__(*args, **kwargs)
#     374
#     375     @property
#
# ~\AppData\Roaming\Python\Python39\site-packages\sympy\printing\latex.py in latex(expr, **settings)
#    2913
#    2914     """
# -> 2915     return LatexPrinter(settings).doprint(expr)
#    2916
#    2917
#
# ~\AppData\Roaming\Python\Python39\site-packages\sympy\printing\latex.py in doprint(self, expr)
#     252
#     253     def doprint(self, expr):
# --> 254         tex = Printer.doprint(self, expr)
#     255
#     256         if self._settings['mode'] == 'plain':
#
# ~\AppData\Roaming\Python\Python39\site-packages\sympy\printing\printer.py in doprint(self, expr)
#     289     def doprint(self, expr):
#     290         """Returns printer's representation for expr (as a string)"""
# --> 291         return self._str(self._print(expr))
#     292
#     293     def _print(self, expr, **kwargs):
#
# ~\AppData\Roaming\Python\Python39\site-packages\sympy\printing\printer.py in _print(self, expr, **kwargs)
#     327                 printmethod = '_print_' + cls.__name__
#     328                 if hasattr(self, printmethod):
# --> 329                     return getattr(self, printmethod)(expr, **kwargs)
#     330             # Unknown object, fall back to the emptyPrinter.
#     331             return self.emptyPrinter(expr)
#
# ~\AppData\Roaming\Python\Python39\site-packages\sympy\printing\latex.py in _print_Mul(self, expr)
#     498     def _print_Mul(self, expr):
#     499         from sympy.core.power import Pow
# --> 500         from sympy.physics.units import Quantity
#     501         from sympy.simplify import fraction
#     502         separator = self._settings['mul_symbol_latex']
#
# ~\AppData\Roaming\Python\Python39\site-packages\sympy\physics\__init__.py in <module>
#       3 """
#       4
# ----> 5 from . import units
#       6 from .matrices import mgamma, msigma, minkowski_tensor, mdft
#       7
#
# ~\AppData\Roaming\Python\Python39\site-packages\sympy\physics\units\__init__.py in <module>
#      34 from .quantities import Quantity
#      35
# ---> 36 from .definitions.dimension_definitions import (
#      37     amount_of_substance, acceleration, action,
#      38     capacitance, charge, conductance, current, energy,
#
# ~\AppData\Roaming\Python\Python39\site-packages\sympy\physics\units\definitions\__init__.py in <module>
# ----> 1 from .unit_definitions import (
#       2     percent, percents,
#       3     permille,
#       4     rad, radian, radians,
#       5     deg, degree, degrees,
#
# ~\AppData\Roaming\Python\Python39\site-packages\sympy\physics\units\definitions\unit_definitions.py in <module>
#     192
#     193 anomalistic_year = anomalistic_years = Quantity("anomalistic_year")
# --> 194 anomalistic_year.set_global_relative_scale_factor(365.259636, day)
#     195
#     196 sidereal_year = sidereal_years = Quantity("sidereal_year")
#
# ~\AppData\Roaming\Python\Python39\site-packages\sympy\physics\units\quantities.py in set_global_relative_scale_factor(self, scale_factor, reference_quantity)
#     104         """
#     105         from sympy.physics.units import UnitSystem
# --> 106         scale_factor = sympify(scale_factor)
#     107         # replace all prefixes by their ratio to canonical units:
#     108         scale_factor = scale_factor.replace(
#
# ~\AppData\Roaming\Python\Python39\site-packages\sympy\core\sympify.py in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     360     conv = converter.get(cls, None)
#     361     if conv is not None:
# --> 362         return conv(a)
#     363
#     364     for superclass in getmro(cls):
#
# ~\AppData\Roaming\Python\Python39\site-packages\sympy\core\numbers.py in __new__(***failed resolving arguments***)
#    1145
#    1146         if precision is None or precision == '':
# -> 1147             precision = mlib.libmpf.dps_to_prec(dps)
#    1148
#    1149         precision = int(precision)
#
# AttributeError: module 'mpmath.libmp' has no attribute 'libmpf'
# 5*x**4

# %%
sym.diff(x**2 * sym.cos(x))
# Out:
# -x**2*sin(x) + 2*x*cos(x)

# %%
sym.diff(1 / (1 + sym.exp(-x)))  #Sigmoid
# Out:
# exp(-x)/(1 + exp(-x))**2

# %%
x, y = sym.symbols('x y')

# %%
sym.diff(x**2 * y, x)
# Out:
# 2*x*y

# %%
sym.diff(x**2 * y, y)
# Out:
# x**2

# %%
x, y, z = sym.symbols('x y z')

# %%
sym.diff(x**2 * y * z**3, z)
# Out:
# 3*x**2*y*z**2

# %%
sym.diff(x**2 * y * z**3, x)
# Out:
# 2*x*y*z**3
